# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrat-2808/google-colab/blob/main/Visualization_with_data_science_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries_df=pd.read_csv("Countries Data.csv")
countries=countries_df
countries.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
c_52=countries.loc[countries["year"]==1952]
c_52.head()
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# 24      Algeria  1952     9279525    Africa    43.077  2449.008185
# 36       Angola  1952     4232095    Africa    30.015  3520.610273
# 48    Argentina  1952    17876956  Americas    62.485  5911.315053

# %%
c_07=countries.loc[countries["year"]==2007]
c_07.head()
# Out:
#         country  year  population continent  life_exp       gdp_cap
# 11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23      Albania  2007     3600523    Europe    76.423   5937.029526
# 35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 47       Angola  2007    12420476    Africa    42.731   4797.231267
# 59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
type(c_52)
# Out:
# pandas.core.frame.DataFrame

# %%
c_merge=c_52.merge(c_07,left_on="country",right_on="country")
c_merge.head()
# Out:
#        country  year_x  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0  Afghanistan    1952       8425333        Asia      28.801   779.445314
# 1      Albania    1952       1282697      Europe      55.230  1601.056136
# 2      Algeria    1952       9279525      Africa      43.077  2449.008185
# 3       Angola    1952       4232095      Africa      30.015  3520.610273
# 4    Argentina    1952      17876956    Americas      62.485  5911.315053
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y
# 0    2007      31889923        Asia      43.828    974.580338
# 1    2007       3600523      Europe      76.423   5937.029526
# 2    2007      33333216      Africa      72.301   6223.367465
# 3    2007      12420476      Africa      42.731   4797.231267
# 4    2007      40301927    Americas      75.320  12779.379640

# %%
c_dropped=c_merge.drop(['year_x','year_y'],axis=1)
c_dropped.head()
# Out:
#            country  population_x continent_x  life_exp_x     gdp_cap_x  \
# 24           China     556263527        Asia      44.000    400.448611
# 58           India     372000000        Asia      37.373    546.565749
# 134  United States     157553000    Americas      68.440  13990.482080
# 59       Indonesia      82052000        Asia      37.468    749.681655
# 14          Brazil      56602560    Americas      50.917   2108.944355
#
#      population_y continent_y  life_exp_y     gdp_cap_y  population_growth
# 24     1318683096        Asia      72.961   4959.114854          762419569
# 58     1110396331        Asia      64.698   2452.210407          738396331
# 134     301139947    Americas      78.242  42951.653090          143586947
# 59      223547000        Asia      70.650   3540.651564          141495000
# 14      190010647    Americas      72.390   9065.800825          133408087

# %%
c_merge['population_growth']=c_merge['population_y'] - c_merge['population_x']
c_merge.head()
# Out:
#        country  year_x  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0  Afghanistan    1952       8425333        Asia      28.801   779.445314
# 1      Albania    1952       1282697      Europe      55.230  1601.056136
# 2      Algeria    1952       9279525      Africa      43.077  2449.008185
# 3       Angola    1952       4232095      Africa      30.015  3520.610273
# 4    Argentina    1952      17876956    Americas      62.485  5911.315053
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y  \
# 0    2007      31889923        Asia      43.828    974.580338
# 1    2007       3600523      Europe      76.423   5937.029526
# 2    2007      33333216      Africa      72.301   6223.367465
# 3    2007      12420476      Africa      42.731   4797.231267
# 4    2007      40301927    Americas      75.320  12779.379640
#
#    population_growth
# 0           23464590
# 1            2317826
# 2           24053691
# 3            8188381
# 4           22424971

# %%
c_merge.shape, type(c_merge)
# Out:
# ((142, 12), pandas.core.frame.DataFrame)

# %%
c_merge=c_merge.sort_values("population_growth",ascending=False).head(10)
c_merge.head(10)
# Out:
#            country  year_x  population_x continent_x  life_exp_x  \
# 24           China    1952     556263527        Asia      44.000
# 58           India    1952     372000000        Asia      37.373
# 134  United States    1952     157553000    Americas      68.440
# 59       Indonesia    1952      82052000        Asia      37.468
# 14          Brazil    1952      56602560    Americas      50.917
# 97        Pakistan    1952      41346560        Asia      43.436
# 8       Bangladesh    1952      46886859        Asia      37.484
# 94         Nigeria    1952      33119096      Africa      36.324
# 82          Mexico    1952      30144317    Americas      50.789
# 101    Philippines    1952      22438691        Asia      47.752
#
#         gdp_cap_x  year_y  population_y continent_y  life_exp_y     gdp_cap_y  \
# 24     400.448611    2007    1318683096        Asia      72.961   4959.114854
# 58     546.565749    2007    1110396331        Asia      64.698   2452.210407
# ...

# %%
names = ['China', 'India', 'United States', 'Indonesia', 'Brazil',
         'Pakistan', 'Bangledesh', 'Nigeria', 'Mexico', 'Philippines']
pop_grow=(c_merge['population_growth']/10**6)

# %%
plt.figure(figsize=(15, 9))
plt.bar(names,pop_grow,width=0.6)
plt.xlabel('Country')
plt.ylabel('Population Growth(MILLIONS)')
plt.title('Top 10 Countries w/the Biggest Population Growth from 1952 to 2007')
plt.xticks(rotation=45)
#zip joins x an y in pairs
for x,y in zip(names,pop_grow):
    label="({:.2f})".format(y)
    plt.annotate(label,#this is the text
                 (x,y),#this is the point to label
                 textcoords="offset points",#how to position the text
                 xytext=(0,10),#distance from text to points(x,y)
                 ha='center')#horizontal allignment can be left,right or center
plt.show()
