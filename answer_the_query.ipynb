# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrat-2808/google-colab/blob/main/answer_the_query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
database='/content/basketball.sqlite'
conn=sqlite3.connect(database)
print("Opened databbase successfully")
# Out:
# Opened databbase successfully

# %%
import pandas as pd
tables=pd.read_sql("""SELECT * FROM sqlite_master WHERE type='table';""",conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    Team_Attributes    Team_Attributes         2
# 1  table      Player_Salary      Player_Salary         5
# 2  table              Draft              Draft        36
# 3  table               Team               Team       314
# 4  table  Player_Attributes  Player_Attributes       315
# 5  table             Player             Player       617
#
#                                                  sql
# 0  CREATE TABLE `Team_Attributes` (`ID`, `ABBREVI...
# 1  CREATE TABLE `Player_Salary` (`slugSeason`, `n...
# 2  CREATE TABLE `Draft` (`yearDraft`, `numberPick...
# 3  CREATE TABLE `Team` (`id`, `full_name`, `abbre...
# 4  CREATE TABLE `Player_Attributes` (`ID`, `FIRST...
# 5  CREATE TABLE `Player` (`id`, `full_name`, `fir...

# %%
teams=pd.read_sql("""SELECT * FROM Team;""",conn)
teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state year_founded
# 0        Atlanta         1949
# 1  Massachusetts         1946
# 2           Ohio         1970
# 3      Louisiana         2002
# 4       Illinois         1966

# %%
salary=pd.read_sql("""SELECT * FROM Player_Salary;""",conn)
salary
# Out:
#      slugSeason            nameTeam         namePlayer    statusPlayer  \
# 0       2020-21       Atlanta Hawks  Bogdan Bogdanovic  current roster
# 1       2021-22       Atlanta Hawks  Bogdan Bogdanovic  current roster
# 2       2022-23       Atlanta Hawks  Bogdan Bogdanovic  current roster
# 3       2023-24       Atlanta Hawks  Bogdan Bogdanovic  current roster
# 4       2020-21       Atlanta Hawks    Brandon Goodwin  current roster
# ...         ...                 ...                ...             ...
# 1287    2020-21  Washington Wizards  Russell Westbrook  current roster
# 1288    2021-22  Washington Wizards  Russell Westbrook  current roster
# 1289    2022-23  Washington Wizards  Russell Westbrook  current roster
# 1290    2020-21  Washington Wizards      Thomas Bryant  current roster
# 1291    2021-22  Washington Wizards      Thomas Bryant  current roster
#
#      isFinalSeason isWaived isOnRoster isNonGuaranteed isTeamOption  \
# ...

# %%
result_1=pd.read_sql("""SELECT AVG(value),MIN(value),MAX(value),
                      SUM(value)FROM Player_Salary;""",conn)
result_1
# Out:
#      AVG(value) MIN(value) MAX(value)    SUM(value)
# 0  9.762008e+06  1000000.0   999200.0  1.261251e+10

# %%
result_2=pd.read_sql("""SELECT COUNT(state) FROM Team;""",conn)
result_2
# Out:
#    COUNT(state)
# 0            30

# %%
result_3=pd.read_sql("""SELECT * FROM Team
                      ORDER BY year_founded;""",conn)
result_3
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612738          Boston Celtics          BOS        Celtics
# 1   1610612744   Golden State Warriors          GSW       Warriors
# 2   1610612752         New York Knicks          NYK         Knicks
# 3   1610612747      Los Angeles Lakers          LAL         Lakers
# 4   1610612758        Sacramento Kings          SAC          Kings
# 5   1610612765         Detroit Pistons          DET        Pistons
# 6   1610612737           Atlanta Hawks          ATL          Hawks
# 7   1610612755      Philadelphia 76ers          PHI          76ers
# 8   1610612764      Washington Wizards          WAS        Wizards
# 9   1610612741           Chicago Bulls          CHI          Bulls
# 10  1610612745         Houston Rockets          HOU        Rockets
# 11  1610612760   Oklahoma City Thunder          OKC        Thunder
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
player=pd.read_sql("""SELECT * FROM Player;""",conn)
player
# Out:
#            id            full_name first_name     last_name is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby         0
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz         0
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar         0
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf         0
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad         0
# ...       ...                  ...        ...           ...       ...
# 4496  1627790           Ante Zizic       Ante         Zizic         1
# 4497    78647             Jim Zoet        Jim          Zoet         0
# 4498    78648            Bill Zopf       Bill          Zopf         0
# 4499  1627826          Ivica Zubac      Ivica         Zubac         1
# 4500    78650           Matt Zunic       Matt         Zunic         0
#
# [4501 rows x 5 columns]
