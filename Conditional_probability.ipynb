# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrat-2808/google-colab/blob/main/Conditional_probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def a_and_b(a,b):
  if a==1:
    prob_student=0.3
    if b==1:
      prob_dining=0.75
    else:
      prob_dining=0.25
    print("Probability of a given b: ", prob_dining)

  if a==2:
    prob_student=0.7
    if b==1:
      prob_dining=0.6
    else:
      prob_dining=0.4
    print("Probability of a given b: ", prob_dining)

  prob_a_and_b=prob_student*prob_dining
  return round(prob_a_and_b,3)

# %%
print("Check the probability of any event occuring. First enter your choices.")
print("Is the student a Fresman? \n 1.Yes \n 2.No")
a=int(input("Enter your choice(1/2) : "))
print("Is student eating in dining hall? \n 1.Yes \n 2.No")
b=int(input("Enter your choice(1/2) : "))
# Out:
# Check the probability of any event occuring. First enter your choices.
# Is the student a Fresman?
#  1.Yes
#  2.No
# Enter your choice(1/2) : 1
# Is student eating in dining hall?
#  1.Yes
#  2.No
# Enter your choice(1/2) : 2

# %%
print("Here is the probability of both the events occuring: ", a_and_b(a,b))
# Out:
# Probability of a given b:  0.25
# Here is the probability of both the events occuring:  0.075

# %%
def prob_a_and_b(a,b,total):
  #probability of event a
  prob_a=orange/total
  #probability of event b
  prob_bga=blue/(total-1)
  #probability of intersection of events a and b
  prob_AandB=prob_a*prob_bga
  #add return statement here
  return round(prob_AandB,3)

# %%
#taking input for total number of orange and blue ball
orange=int(input("Enter number of orange balls: "))
blue=int(input("Enter number of blue balls: "))
total=orange+blue
# Out:
# Enter number of orange balls: 6
# Enter number of blue balls: 4

# %%
#call function for final result
print("probability of getting 1st orange and 2nd blue ball: ")
print(prob_a_and_b(orange,blue,total))
# Out:
# probability of getting 1st orange and 2nd blue ball:
# 0.267

# %%
RS=int(input("Enter number of red shirts: "))
BS=int(input("Enter number of blue shirts: "))
WS=int(input("Enter number of white shirts: "))
total=RS+BS+WS
# Out:
# Enter number of red shirts: 45
# Enter number of blue shirts: 32
# Enter number of white shirts: 41

# %%
prob_a=BS/total
prob_b=RS/total
prob_bga=prob_b
prob_a_and_b=prob_a*prob_b
print("Probability that the second shirt is red given the first shirt is blue: ")
print(round(prob_bga),3)
print("Probability that the second shirt is red and the first shirt is blue: ")
print(round(prob_a_and_b,3))
# Out:
# Probability that the second shirt is red given the first shirt is blue:
# 0 3
# Probability that the second shirt is red and the first shirt is blue:
# 0.103
